# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"data\Mall_Customers.csv")
df.columns = ["id","sex","age","annInc","spSco"]
df.head()
# Out:
#    id     sex  age  annInc  spSco
# 0   1    Male   19      15     39
# 1   2    Male   21      15     81
# 2   3  Female   20      16      6
# 3   4  Female   23      16     77
# 4   5  Female   31      17     40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      200 non-null    int64
#  1   sex     200 non-null    object
#  2   age     200 non-null    int64
#  3   annInc  200 non-null    int64
#  4   spSco   200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe().T
# Out:
#         count    mean        std   min    25%    50%     75%    max
# id      200.0  100.50  57.879185   1.0  50.75  100.5  150.25  200.0
# age     200.0   38.85  13.969007  18.0  28.75   36.0   49.00   70.0
# annInc  200.0   60.56  26.264721  15.0  41.50   61.5   78.00  137.0
# spSco   200.0   50.20  25.823522   1.0  34.75   50.0   73.00   99.0

# %%
df.isnull().sum()
# Out:
# id        0
# sex       0
# age       0
# annInc    0
# spSco     0
# dtype: int64

# %%
df.hist(figsize=(10,7))
# Out:
# array([[<Axes: title={'center': 'id'}>, <Axes: title={'center': 'age'}>],
#        [<Axes: title={'center': 'annInc'}>,
#         <Axes: title={'center': 'spSco'}>]], dtype=object)

# %%
sns.boxplot(data=df,x="annInc")
# Out:
# <Axes: xlabel='annInc'>

# %%
sns.boxplot(data=df,x="spSco")
# Out:
# <Axes: xlabel='spSco'>

# %%
sns.scatterplot(data=df,x="annInc",y="spSco")
# Out:
# <Axes: xlabel='annInc', ylabel='spSco'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True);

# %%
sns.scatterplot(x=df["annInc"],y=df["age"])
# Out:
# <Axes: xlabel='annInc', ylabel='age'>

# %%
sns.scatterplot(x=df["spSco"],y=df["age"])
# Out:
# <Axes: xlabel='spSco', ylabel='age'>

# %%
sns.barplot(x=df["sex"],y=df["annInc"])
# Out:
# <Axes: xlabel='sex', ylabel='annInc'>

# %%
sns.barplot(x=df["sex"],y=df["spSco"])
# Out:
# <Axes: xlabel='sex', ylabel='spSco'>
